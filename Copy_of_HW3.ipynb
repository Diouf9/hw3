# %% [markdown]
# Please see examples we did in class. Questions are just variations of what we did earlier.

# %% [markdown]
# **Q1**. Please read WorldCupMatches.csv to a data frame to proceed

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/DATA/WorldCupMatches.csv')
print(df.shape)
df.head()
# Out:
# (852, 20)
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# **Q2**. Using seaborn's displot draw density curves to show the distributions of Home Team Goals for every year.

# %%
plt.figure(figsize=(15,10))
figsize=(15,10)
sns.displot(df['Home Team Goals'])

# %% [markdown]
# **Q3** Draw violin plots to summarize Home Team Goals distributions for each year by using seaborn. Notice that labels are really cluttered. Then please refer to the earlier notebooks to have labels to appear on only select years which end with 0. You can use ax handle to call ax.set_xticklables(labels) for the labels your prepared.

# %%
#draw violin plot to summarize HTG/year with seaborn. Labels should be years ending w/0.
plt.figure(figsize=(15,10))
sns.violinplot(x='Year', y='Home Team Goals', data=df)
labels=('1930','1950','1970','1990','2010')
ax.set_xticklabels(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4ebb5b6bf1a2> in <cell line: 5>()
#       3 sns.violinplot(x='Year', y='Home Team Goals', data=df)
#       4 labels=('1930','1950','1970','1990','2010')
# ----> 5 ax.set_xticklabels(labels)
#       6
#
# NameError: name 'ax' is not defined

# %% [markdown]
# **Q4** Please install joypy. Then visualize distributions for Home Team Goals and Away Team Goals' for each year. Once you visualize, please add  plt.style.use('seaborn-white') to see how colors change in your second run. Please also add the legend which you can find from the function prototype.

# %%
# !pip install joypy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: scipy>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from joypy) (1.10.1)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from joypy) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from joypy) (3.7.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from joypy) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.0->joypy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.20.0->joypy) (2022.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->joypy) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->joypy) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->joypy) (1.16.0)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6

# %%
import joypy 
data=df[['Year','Home Team Goals', 'Away Team Goals']]
fig, axs=joypy.joyplot(data, by='Year', overlap=2, legend=True, figsize=(16,10))

# %% [markdown]
# **Q5** Please use groupby function on Home Team Initials to see the sum of Home Team Goals which can be saved to another data frame by adding .reset_index() end the end of your line.
#
# Then use your new data frame to visualize those total Home Team Goals for your top 5 countries with a bar plot (You can use Home Team Initials). You can use use df.sort_values() function on your data frame by tweaking the ascending option.
#
# Notice that your x-axis will be having country initials, and y-axis will show the total number of Home Team Goals.

# %%
df.groupby(['Home Team Initials'])['Home Team Goals'].count()
# Out:
# Home Team Initials
# ALG     6
# ANG     1
# ARG    54
# AUS     6
# AUT    13
#        ..
# URU    28
# USA    15
# WAL     1
# YUG    17
# ZAI     2
# Name: Home Team Goals, Length: 77, dtype: int64

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France                4
# 1         Parque Central      Montevideo             USA                3
# 2         Parque Central      Montevideo      Yugoslavia                2
# 3                Pocitos      Montevideo         Romania                3
# 4         Parque Central      Montevideo       Argentina                1
# ..                   ...              ...            ...              ...
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 0                  1         Mexico
# 1                  0        Belgium
# 2                  1         Brazil
# 3                  1           Peru
# 4                  0         France
# ..               ...            ...                                    ...
# 847                0     Costa Rica  Netherlands win on penalties (4 - 3)
# 848                7        Germany
# 849                0      Argentina    Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina          Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0        4444.0                     3                     0
# 1       18346.0                     2                     0
# 2       24059.0                     2                     0
# 3        2549.0                     1                     0
# 4       23409.0                     0                     0
# ..          ...                   ...                   ...
# 847     51179.0                     0                     0
# 848     58141.0                     0                     5
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                     Referee                  Assistant 1  \
# 0    LOMBARDI Domingo (URU)        CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)     MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)      VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)          LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)         SAUCEDO Ulises (BOL)
# ..                      ...                          ...
# 847   Ravshan IRMATOV (UZB)  RASULOV Abduxamidullo (UZB)
# 848   RODRIGUEZ Marco (MEX)      TORRENTERA Marvin (MEX)
# 849      C�neyt �AKIR (TUR)         DURAN Bahattin (TUR)
# 850   HAIMOUDI Djamel (ALG)         ACHIK Redouane (MAR)
# 851    Nicola RIZZOLI (ITA)        Renato FAVERANI (ITA)
#
#                     Assistant 2  RoundID    MatchID Home Team Initials  \
# 0           REGO Gilberto (BRA)      201       1096                FRA
# 1         WARNKEN Alberto (CHI)      201       1090                USA
# 2           BALWAY Thomas (FRA)      201       1093                YUG
# 3      MATEUCCI Francisco (URU)      201       1098                ROU
# 4    RADULESCU Constantin (ROU)      201       1085                ARG
# ..                          ...      ...        ...                ...
# 847    KOCHKAROV Bakhadyr (KGZ)   255953  300186488                NED
# 848       QUINTERO Marcos (MEX)   255955  300186474                BRA
# 849           ONGUN Tarik (TUR)   255955  300186490                NED
# 850     ETCHIALI Abdelhak (ALG)   255957  300186502                BRA
# 851        Andrea STEFANI (ITA)   255959  300186501                GER
#
#     Away Team Initials
# 0                  MEX
# 1                  BEL
# 2                  BRA
# 3                  PER
# 4                  FRA
# ..                 ...
# 847                CRC
# 848                GER
# 849                ARG
# 850                NED
# 851                ARG
#
# [852 rows x 20 columns]>

# %%
import matplotlib.pyplot as plt

#Notice that your x-axis will be having country initials, and y-axis will show the total number of Home Team Goals.
HomeTeamInitials = ['AUT', 'USA', 'YUG', 'URU','ARG']
HomeTeamGoals = ['13','15','17','28','54']

plt.bar(HomeTeamInitials, HomeTeamGoals)
plt.title('Total Number of Home team Goals by Countries')
plt.xlabel('Country Initials')
plt.ylabel('Home Team Goals')
plt.show()

# %% [markdown]
# **Q6** Please extract the rows for your top 4 countries (Home Team Initials') with the help of the previous question's answer. Then use joyplot again to visualize densities for 'Home Team Goals' and	'Away Team Goals' on the horizantal axis. Notice that your y-axis labels will be your country initials (Home Team Initials'). Make sure that your legend is visible and use 'dark_background' by calling plt.style.use again.

# %%
import numpy as np
df = pd.DataFrame({'Home Team Goals': np.round(np.random.exponential(1,1000)*100)+1})
#print(np.random.exponential(1,1000))
df.head()
# Out:
#    Home Team Goals
# 0            195.0
# 1            245.0
# 2              8.0
# 3             35.0
# 4            345.0

# %%
df = pd.DataFrame({'Away Team Goals': np.round(np.random.exponential(1,1000)*100)+1})
df.head()
# Out:
#    Away Team Goals
# 0            141.0
# 1             23.0
# 2             63.0
# 3             55.0
# 4             13.0

# %%
sns.displot(df['Home Team Goals'], kind='kde' )
plt.style(dark_background)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-a669f06421b2> in <cell line: 2>()
#       1 sns.displot(df['Home Team Goals'], kind='kde' )
# ----> 2 plt.style(dark_background)
#
# NameError: name 'dark_background' is not defined

# %%
ax = sns.displot(df['Away Team Goals'], kind='kde' )
ax.set(ylabel = 'County Initials')

# %% [markdown]
# **Q7** Please install seaborn_qqplot as shown below. Then draw a qqplot to compare probability distributions of Home Team Goals and Away Team Goals. Please comment on your finding. Do you think their distributions agree with each other? Please justify your answer by explaining the figure you obtained.

# %%
# !pip install seaborn_qqplot
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting seaborn_qqplot
#   Downloading seaborn_qqplot-0.5.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from seaborn_qqplot) (0.12.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from seaborn_qqplot) (0.8.10)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from seaborn_qqplot) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from seaborn_qqplot) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->seaborn_qqplot) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->seaborn_qqplot) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas->seaborn_qqplot) (1.22.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.9/dist-packages (from seaborn->seaborn_qqplot) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->seaborn_qqplot) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn->seaborn_qqplot) (3.15.0)
# Installing collected packages: seaborn_qqplot
# Successfully installed seaborn_qqplot-0.5.0

# %%
from seaborn_qqplot import pplot #seaborn-qqplot is a seaborn extension adding qqplots.
plt.style.use('ggplot') #this is to change the color theme. 
from scipy.stats import norm

# %%
pplot(df, x='Home Team Goals', y='Away Team Goals', kind = 'qq', display_kws={"identity":True}, height=4, aspect=2)
pplot(df, x='Home Team Goals', y=norm, kind = 'qq', display_kws={"identity":True}, height=4, aspect=2)

# %% [markdown]
# I think the findings do complement each other. The norm for the home team goals are more in line with the average, which would be expected as factors such as the team being used to their home territory come into play. As for the first graph, it makes sense it would deviate from the norm seeing as one team would be more prominent than the other. The first graph would have more factors at play, which explains why the rate of goals are higher than the first.
